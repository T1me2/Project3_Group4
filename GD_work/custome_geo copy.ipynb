# %%
import pymongo 
import json
import pandas as pd
from pymongo import MongoClient
from flask import jsonify

# %%
#open json file
x = open('resources\data.json')

#return json object
data = json.load(x)
mydata = data['features']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/f5/fmwr4j4s4gv2xp3_q6xpt02w0000gn/T/ipykernel_62180/1103978145.py in <module>
#       1 #open json file
# ----> 2 x = open('resources\data.json')
#       3
#       4 #return json object
#       5 data = json.load(x)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources\\data.json'

# %%
data

# %%
mydata

# %%
int(mydata[0]['properties']['STATE'])

# %%
mydata[0]['properties']

# %%
#read in walkability_df

walk_csv = pd.read_csv('./static/data/walkability.csv')
# walk_data = pd.DataFrame(walk_csv)
walk_csv = walk_csv.groupby(['STATEFP', 'COUNTYFP'], reset_index=False).sum()
walk_csv = walk_csv['STATEFP', 'COUNTYFP', 'Shape_Area']
# Out:
#                   OBJECTID       GEOID10       GEOID20   TRACTCE  BLKGRPCE  \
# STATEFP COUNTYFP
# 1       1           710130  3.203266e+11  3.203266e+11    660610        63
#         3          2098717  9.428401e+11  9.428401e+11   2014698       197
#         5           535198  2.313686e+11  2.313686e+11  21861100        42
#         7           336151  1.510515e+11  1.510515e+11    150044        40
#         9           815170  3.531676e+11  3.531676e+11   1763625        91
# ...                    ...           ...           ...       ...       ...
# 72      151        5258512  1.732800e+13  1.732800e+13  22861300        46
#         153        6143666  2.021600e+13  2.021600e+13  21010534        54
# 78      10         9489520  3.276000e+13  3.354000e+13  41763200        89
#         20         1765822  6.240000e+12  6.240000e+12   7641100        16
#         30         8386602  2.964000e+13  2.964000e+13  36532800        82
#
#                       CSA       CBSA  CBSA_POP  CBSA_EMP  CBSA_WRK  ...  \
# STATEFP COUNTYFP                                                    ...
# 1       1         12416.0  1083520.0  11954848   5292576   4791424  ...
#         3         35720.0  1814200.0  19562058   6745440   7793446  ...
#         5             0.0   497720.0    645334    189405    241822  ...
#         7          2130.0   207300.0  16238415   7394925   6814005  ...
#         9          4970.0   483700.0  37889635  17254825  15899345  ...
# ...                   ...        ...       ...       ...       ...  ...
# 72      151       11760.0  1007520.0  51417408         0         0  ...
#         153       12152.0  1386000.0   2609992         0         0  ...
# 78      10            0.0        0.0         0         0         0  ...
#         20            0.0        0.0         0         0         0  ...
#         30            0.0        0.0         0         0         0  ...
#
#                       D5DRI       D5DE      D5DEI  D2A_Ranked  D2B_Ranked  \
# STATEFP COUNTYFP
# 1       1        -3199968.0 -3199968.0 -3199968.0         293         300
#         3        -9399906.0 -9399906.0 -9399906.0        1179        1207
#         5        -2299977.0 -2299977.0 -2299977.0         281         219
#         7        -1499985.0 -1499985.0 -1499985.0         169         160
#         9        -3499965.0 -3499965.0 -3499965.0         318         344
# ...                     ...        ...        ...         ...         ...
# 72      151      -2399976.0 -2399976.0 -2399976.0          24          24
#         153      -2799972.0 -2799972.0 -2799972.0          28          28
# 78      10       -4299957.0 -4299957.0 -4299957.0          43          43
#         20        -799992.0  -799992.0  -799992.0           8           8
#         30       -3799962.0 -3799962.0 -3799962.0          38          38
#
#                   D3B_Ranked  D4A_Ranked  NatWalkInd  Shape_Length  \
# STATEFP COUNTYFP
# 1       1                174          32  167.500000  8.703273e+05
#         3                532          94  606.333333  3.000316e+06
#         5                 85          23  119.333333  1.116346e+06
#         7                 47          15   75.500000  7.596355e+05
#         9                124          35  163.333333  1.366601e+06
# ...                      ...         ...         ...           ...
# 72      151              197          24   81.666667  3.430403e+05
#         153              327          28  127.666667  3.238250e+05
# 78      10               456          43  180.666667  6.739424e+05
#         20                68           8   28.000000  2.479753e+05
#         30               452          38  176.000000  5.694787e+05
#
#                     Shape_Area
# STATEFP COUNTYFP
# 1       1         1.565309e+09
#         3         5.250602e+09
#         5         2.342684e+09
#         7         1.621770e+09
#         9         1.685119e+09
# ...                        ...
# 72      151       2.155977e+08
#         153       1.769972e+08
# 78      10        8.615598e+08
#         20        2.376683e+08
#         30        7.990307e+08
#
# [3233 rows x 113 columns]

# %%
walk_data.dtypes
# Out:
# Unnamed: 0             int64
# state                  int64
# county                 int64
# walkability_score    float64
# unique_id              int64
# dtype: object

# %%
for  x in range(len(walk_data['walkability_score'])):
    for y in mydata:
        if walk_data.loc[x,'state'] == int(y['properties']['STATE'])\
        and walk_data.loc[x,'county'] == int(y['properties']['COUNTY']):
            y['properties']['walkability_score'] = walk_data.loc[x, 'walkability_score']
            y['properties']['unique_id'] = int(walk_data.loc[x,'unique_id'])

# %%
# mydata['properties']['STATE']

# %%
mydata[0]
# Out:
# {'type': 'Feature',
#  'properties': {'GEO_ID': '0500000US01029',
#   'STATE': '01',
#   'COUNTY': '029',
#   'NAME': 'Cleburne',
#   'LSAD': 'County',
#   'CENSUSAREA': 560.1,
#   'walkability_score': 4.606060606090909,
#   'unique_id': 1029},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-85.388717, 33.913044],
#     [-85.380885, 33.873508],
#     [-85.379455, 33.866291],
#     [-85.377426, 33.856047],
#     [-85.376403, 33.850656],
#     [-85.364595, 33.788446],
#     [-85.361844, 33.773951],
#     [-85.360491, 33.767958],
#     [-85.357402, 33.750104],
#     [-85.355252, 33.739245],
#     [-85.344054, 33.682684],
#     [-85.342722, 33.675953],
#     [-85.323792, 33.580339],
#     [-85.31534, 33.537646],
#     [-85.314994, 33.535898],
#     [-85.314843, 33.534951],
#     [-85.314091, 33.530218],
#     [-85.313999, 33.529807],
#     [-85.304439, 33.482884],
#     [-85.308211, 33.481579],
#     [-85.30925, 33.483137],
#     [-85.314852, 33.487603],
#     [-85.316028, 33.488267],
#     [-85.320893, 33.488359],
#     [-85.324856, 33.489161],
#     [-85.331061, 33.491014],
#     [-85.33828, 33.4947],
#     [-85.342544, 33.495961],
#     [-85.344923, 33.497608],
#     [-85.346705, 33.501148],
#     [-85.349958, 33.501216],
#     [-85.351594, 33.4996],
#     [-85.354491, 33.498866],
#     [-85.352576, 33.494538],
#     [-85.352573, 33.492438],
#     [-85.355315, 33.49248],
#     [-85.497455, 33.494624],
#     [-85.501645, 33.494456],
#     [-85.51731, 33.494524],
#     [-85.52513, 33.494781],
#     [-85.527515, 33.494608],
#     [-85.539922, 33.494743],
#     [-85.563763, 33.495081],
#     [-85.565653, 33.494992],
#     [-85.623387, 33.495371],
#     [-85.623645, 33.495373],
#     [-85.627835, 33.495624],
#     [-85.643482, 33.495885],
#     [-85.66722, 33.496293],
#     [-85.680346, 33.496623],
#     [-85.740983, 33.498376],
#     [-85.765427, 33.498593],
#     [-85.765308, 33.496862],
#     [-85.765631, 33.483477],
#     [-85.781244, 33.483625],
#     [-85.782689, 33.483638],
#     [-85.782735, 33.469349],
#     [-85.887782, 33.469427],
#     [-85.887675, 33.476768],
#     [-85.870053, 33.476757],
#     [-85.869308, 33.491574],
#     [-85.852421, 33.491644],
#     [-85.85189, 33.498742],
#     [-85.849839, 33.49969],
#     [-85.796852, 33.541849],
#     [-85.796054, 33.55622],
#     [-85.744118, 33.556075],
#     [-85.742348, 33.586553],
#     [-85.742202, 33.600002],
#     [-85.737379, 33.599823],
#     [-85.724517, 33.59943],
#     [-85.724953, 33.613539],
#     [-85.72367, 33.613492],
#     [-85.72365, 33.613491],
#     [-85.723074, 33.613505],
#     [-85.689954, 33.612909],
#     [-85.69014, 33.615815],
#     [-85.690716, 33.625105],
#     [-85.690684, 33.627789],
#     [-85.674932, 33.627254],
#     [-85.65581, 33.627166],
#     [-85.655549, 33.638127],
#     [-85.651295, 33.637972],
#     [-85.651283, 33.64157],
#     [-85.64719, 33.641529],
#     [-85.64704, 33.648772],
#     [-85.638579, 33.648413],
#     [-85.638586, 33.649158],
#     [-85.638049, 33.773339],
#     [-85.621245, 33.773508],
#     [-85.621019, 33.782331],
#     [-85.62089, 33.787944],
#     [-85.603469, 33.787755],
#     [-85.603465, 33.788474],
#     [-85.603391, 33.802344],
#     [-85.585985, 33.802095],
#     [-85.585201, 33.84592],
#     [-85.636882, 33.846495],
#     [-85.637126, 33.846497],
#     [-85.637012, 33.875273],
#     [-85.637014, 33.875944],
#     [-85.601899, 33.874865],
#     [-85.601913, 33.875101],
#     [-85.601858, 33.88975],
#     [-85.597063, 33.889703],
#     [-85.532482, 33.889152],
#     [-85.531812, 33.903049],
#     [-85.530094, 33.941423],
#     [-85.49582, 33.942394],
#     [-85.495289, 33.95691],
#     [-85.425627, 33.957069],
#     [-85.425444, 33.960645],
#     [-85.407831, 33.960548],
#     [-85.407637, 33.964204],
#     [-85.398837, 33.964129],
#     [-85.391495, 33.927068],
#     [-85.388717, 33.913044]]]}}

# %%
walk_data['state'][1]

# %%
#read in county population information
pop_csv = pd.read_csv('resources\county_population_df.csv')
pop_data = pd.DataFrame(pop_csv)
pop_data
# Out:
#       Unnamed: 0  state  county  population  households  unique_id
# 0              0      1       1       55200     21115.0       1001
# 1              1      1       3      208107     78622.0       1003
# 2              2      1       5       25782      9186.0       1005
# 3              3      1       7       22527      6840.0       1007
# 4              4      1       9       57645     20600.0       1009
# ...          ...    ...     ...         ...         ...        ...
# 3228        3228     72     151       34149     11722.0      72151
# 3229        3229     72     153       36439     10790.0      72153
# 3230        3230     78      10       50601     19765.0      78010
# 3231        3231     78      20        4170      1894.0      78020
# 3232        3232     78      30       51634     21555.0      78030
#
# [3233 rows x 6 columns]

# %%
for  x in range(len(pop_data['population'])):
    for y in mydata:
        if pop_data.loc[x,'state'] == int(y['properties']['STATE'])\
        and pop_data.loc[x,'county'] == int(y['properties']['COUNTY']):
            y['properties']['population'] = int(pop_data.loc[x, 'population'])

# %%
mydata[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f5/fmwr4j4s4gv2xp3_q6xpt02w0000gn/T/ipykernel_62180/3209961193.py in <module>
# ----> 1 mydata[0]
#
# NameError: name 'mydata' is not defined

# %%
#read in publis school info
school_csv = pd.read_csv('resources\Public_School_Characteristics_-_Current.csv')
school_data = pd.DataFrame(school_csv)
school_data
school_df = school_data[['OBJECTID', 'STABR', 'SCH_NAME', 'NMCNTY', 'TOTFRL', 'TOTAL', 'SCHOOL_LEVEL']]
school_df
# Out:
# C:\Anaconda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         OBJECTID STABR                           SCH_NAME             NMCNTY  \
# 0              1    AL          Albertville Middle School    Marshall County
# 1              2    AL            Albertville High School    Marshall County
# 2              3    AL    Albertville Intermediate School    Marshall County
# 3              4    AL      Albertville Elementary School    Marshall County
# 4              5    AL  Albertville Kindergarten and PreK    Marshall County
# ...          ...   ...                                ...                ...
# 100717    101658    VI         LOCKHART ELEMENTARY SCHOOL  St. Thomas Island
# 100718    101659    VI    ULLA F MULLER ELEMENTARY SCHOOL  St. Thomas Island
# 100719    101660    VI    YVONNE BOWSKY ELEMENTARY SCHOOL  St. Thomas Island
# 100720    101661    VI         CANCRYN JUNIOR HIGH SCHOOL  St. Thomas Island
# 100721    101662    VI       BERTHA BOSCHULTE JUNIOR HIGH  St. Thomas Island
#
#         TOTFRL   TOTAL SCHOOL_LEVEL
# 0        332.0   908.0       Middle
# 1        456.0  1606.0         High
# 2        330.0   891.0       Middle
# 3        397.0   908.0   Elementary
# 4        181.0   556.0   Elementary
# ...        ...     ...          ...
# 100717   325.0   328.0   Elementary
# 100718   474.0   477.0   Elementary
# 100719   394.0   397.0   Elementary
# 100720   760.0   763.0       Middle
# 100721   574.0   577.0       Middle
#
# [100722 rows x 7 columns]

# %%
school_df.dtypes

# %%
#drop county from all the county names
county_list = school_df['NMCNTY']
semi_cleaned_list = []
for county in county_list:
    x = county.split(" County")
    semi_cleaned_list.append(x)
semi_cleaned_list

for x in semi_cleaned_list:
    while('' in x):
        x.remove('')
semi_cleaned_list   

final_list = []
for x in semi_cleaned_list:
    for y in x:
        final_list.append(y)
len(final_list)
# Out:
# 100722

# %%
school_df['county'] = final_list
school_df_sum = school_df.groupby(['STABR', 'county']).sum().reset_index()
school_df_sum['state_id'] = ''
school_df_sum
# Out:
# C:\Anaconda\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      STABR                      county  OBJECTID  TOTFRL    TOTAL state_id
# 0       AK      Aleutians East Borough      6446     0.0    228.0
# 1       AK  Aleutians West Census Area     11279     0.0    477.0
# 2       AK      Anchorage Municipality    174656     0.0  42607.0
# 3       AK          Bethel Census Area     70481     0.0   4974.0
# 4       AK         Bristol Bay Borough      6766     0.0    119.0
# ...    ...                         ...       ...     ...      ...      ...
# 3305    WY                  Sweetwater   2812640  2252.0   7500.0
# 3306    WY                       Teton   1205480   132.0   2752.0
# 3307    WY                       Uinta   1404607  1447.0   4149.0
# 3308    WY                    Washakie    703453   421.0   1277.0
# 3309    WY                      Weston    703048   240.0    999.0
#
# [3310 rows x 6 columns]

# %%
school_df_sum
# Out:
#      STABR                      county  OBJECTID  TOTFRL    TOTAL state_id
# 0       AK      Aleutians East Borough      6446     0.0    228.0
# 1       AK  Aleutians West Census Area     11279     0.0    477.0
# 2       AK      Anchorage Municipality    174656     0.0  42607.0
# 3       AK          Bethel Census Area     70481     0.0   4974.0
# 4       AK         Bristol Bay Borough      6766     0.0    119.0
# ...    ...                         ...       ...     ...      ...      ...
# 3305    WY                  Sweetwater   2812640  2252.0   7500.0
# 3306    WY                       Teton   1205480   132.0   2752.0
# 3307    WY                       Uinta   1404607  1447.0   4149.0
# 3308    WY                    Washakie    703453   421.0   1277.0
# 3309    WY                      Weston    703048   240.0    999.0
#
# [3310 rows x 6 columns]

# %%
stateDict = {1:'AL', 2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',
                11:'DC', 12:'FL', 13:'GA', 15:'HI', 16:'ID', 17:'IL', 18:'IN', 19:'IA',
                20:'KS', 21:'KY', 22:'LA', 23:'ME', 24:'MD', 25:'MA', 26:'MI', 27:'MN',
                28:'MS', 29:'MO', 30:'MT', 31:'NE', 32:'NV', 33:'NH', 34:'NJ', 35:'NM',
                36:'NY', 37:'NC', 38:'ND', 39:'OH', 40:'OK', 41:'OR', 42:'PA', 72:'PR',
                44:'RI', 45:'SC', 46:'SD', 47:'TN', 48:'TX', 49:'UT', 50:'VT', 51:'VA',
                53:'WA', 54:'WV', 55:'WI', 56:'WY'
            };

# %%
state_id = []
state_abv = []
for key in stateDict.keys():
    state_id.append(key)
for value in stateDict.values():
    state_abv.append(value)
stateinfo = {'state_id': state_id, 'state_abv': state_abv}
state_num_df = pd.DataFrame(stateinfo)
state_num_df
# Out:
#     state_id state_abv
# 0          1        AL
# 1          2        AK
# 2          4        AZ
# 3          5        AR
# 4          6        CA
# 5          8        CO
# 6          9        CT
# 7         10        DE
# 8         11        DC
# 9         12        FL
# 10        13        GA
# 11        15        HI
# 12        16        ID
# 13        17        IL
# 14        18        IN
# 15        19        IA
# 16        20        KS
# 17        21        KY
# 18        22        LA
# 19        23        ME
# 20        24        MD
# 21        25        MA
# 22        26        MI
# 23        27        MN
# 24        28        MS
# 25        29        MO
# 26        30        MT
# 27        31        NE
# 28        32        NV
# 29        33        NH
# 30        34        NJ
# 31        35        NM
# 32        36        NY
# 33        37        NC
# 34        38        ND
# 35        39        OH
# 36        40        OK
# 37        41        OR
# 38        42        PA
# 39        72        PR
# 40        44        RI
# 41        45        SC
# 42        46        SD
# 43        47        TN
# 44        48        TX
# 45        49        UT
# 46        50        VT
# 47        51        VA
# 48        53        WA
# 49        54        WV
# 50        55        WI
# 51        56        WY

# %%
state_num_df.dtypes

# %%
for y in range(len(state_num_df['state_abv'])):
    for x in range(len(school_df_sum['STABR'])):
        if state_num_df.loc[y,'state_abv'] == school_df_sum.loc[x,'STABR']:
            school_df_sum.loc[x, 'state_id'] = state_num_df.loc[y, 'state_id']
school_df_sum
# Out:
#      STABR                      county  OBJECTID  TOTFRL    TOTAL state_id
# 0       AK      Aleutians East Borough      6446     0.0    228.0        2
# 1       AK  Aleutians West Census Area     11279     0.0    477.0        2
# 2       AK      Anchorage Municipality    174656     0.0  42607.0        2
# 3       AK          Bethel Census Area     70481     0.0   4974.0        2
# 4       AK         Bristol Bay Borough      6766     0.0    119.0        2
# ...    ...                         ...       ...     ...      ...      ...
# 3305    WY                  Sweetwater   2812640  2252.0   7500.0       56
# 3306    WY                       Teton   1205480   132.0   2752.0       56
# 3307    WY                       Uinta   1404607  1447.0   4149.0       56
# 3308    WY                    Washakie    703453   421.0   1277.0       56
# 3309    WY                      Weston    703048   240.0    999.0       56
#
# [3310 rows x 6 columns]

# %%
school_df_sum.dtypes
# Out:
# STABR        object
# county       object
# OBJECTID      int64
# TOTFRL      float64
# TOTAL       float64
# state_id     object
# dtype: object

# %%
for  x in range(len(school_df_sum['TOTAL'])):
    for y in mydata:
        if school_df_sum.loc[x,'state_id'] == int(y['properties']['STATE'])\
        and school_df_sum.loc[x,'county'] == y['properties']['NAME']:
            y['properties']['student_pop'] = int(school_df_sum.loc[x, 'TOTAL'])
            
            
#             y['properties']['population'] = int(pop_data.loc[x, 'population'])

# %%
mydata[0]
# Out:
# {'type': 'Feature',
#  'properties': {'GEO_ID': '0500000US01029',
#   'STATE': '01',
#   'COUNTY': '029',
#   'NAME': 'Cleburne',
#   'LSAD': 'County',
#   'CENSUSAREA': 560.1,
#   'walkability_score': 4.606060606090909,
#   'unique_id': 1029,
#   'population': 14938,
#   'student_pop': 2510},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-85.388717, 33.913044],
#     [-85.380885, 33.873508],
#     [-85.379455, 33.866291],
#     [-85.377426, 33.856047],
#     [-85.376403, 33.850656],
#     [-85.364595, 33.788446],
#     [-85.361844, 33.773951],
#     [-85.360491, 33.767958],
#     [-85.357402, 33.750104],
#     [-85.355252, 33.739245],
#     [-85.344054, 33.682684],
#     [-85.342722, 33.675953],
#     [-85.323792, 33.580339],
#     [-85.31534, 33.537646],
#     [-85.314994, 33.535898],
#     [-85.314843, 33.534951],
#     [-85.314091, 33.530218],
#     [-85.313999, 33.529807],
#     [-85.304439, 33.482884],
#     [-85.308211, 33.481579],
#     [-85.30925, 33.483137],
#     [-85.314852, 33.487603],
#     [-85.316028, 33.488267],
#     [-85.320893, 33.488359],
#     [-85.324856, 33.489161],
#     [-85.331061, 33.491014],
#     [-85.33828, 33.4947],
#     [-85.342544, 33.495961],
#     [-85.344923, 33.497608],
#     [-85.346705, 33.501148],
#     [-85.349958, 33.501216],
#     [-85.351594, 33.4996],
#     [-85.354491, 33.498866],
#     [-85.352576, 33.494538],
#     [-85.352573, 33.492438],
#     [-85.355315, 33.49248],
#     [-85.497455, 33.494624],
#     [-85.501645, 33.494456],
#     [-85.51731, 33.494524],
#     [-85.52513, 33.494781],
#     [-85.527515, 33.494608],
#     [-85.539922, 33.494743],
#     [-85.563763, 33.495081],
#     [-85.565653, 33.494992],
#     [-85.623387, 33.495371],
#     [-85.623645, 33.495373],
#     [-85.627835, 33.495624],
#     [-85.643482, 33.495885],
#     [-85.66722, 33.496293],
#     [-85.680346, 33.496623],
#     [-85.740983, 33.498376],
#     [-85.765427, 33.498593],
#     [-85.765308, 33.496862],
#     [-85.765631, 33.483477],
#     [-85.781244, 33.483625],
#     [-85.782689, 33.483638],
#     [-85.782735, 33.469349],
#     [-85.887782, 33.469427],
#     [-85.887675, 33.476768],
#     [-85.870053, 33.476757],
#     [-85.869308, 33.491574],
#     [-85.852421, 33.491644],
#     [-85.85189, 33.498742],
#     [-85.849839, 33.49969],
#     [-85.796852, 33.541849],
#     [-85.796054, 33.55622],
#     [-85.744118, 33.556075],
#     [-85.742348, 33.586553],
#     [-85.742202, 33.600002],
#     [-85.737379, 33.599823],
#     [-85.724517, 33.59943],
#     [-85.724953, 33.613539],
#     [-85.72367, 33.613492],
#     [-85.72365, 33.613491],
#     [-85.723074, 33.613505],
#     [-85.689954, 33.612909],
#     [-85.69014, 33.615815],
#     [-85.690716, 33.625105],
#     [-85.690684, 33.627789],
#     [-85.674932, 33.627254],
#     [-85.65581, 33.627166],
#     [-85.655549, 33.638127],
#     [-85.651295, 33.637972],
#     [-85.651283, 33.64157],
#     [-85.64719, 33.641529],
#     [-85.64704, 33.648772],
#     [-85.638579, 33.648413],
#     [-85.638586, 33.649158],
#     [-85.638049, 33.773339],
#     [-85.621245, 33.773508],
#     [-85.621019, 33.782331],
#     [-85.62089, 33.787944],
#     [-85.603469, 33.787755],
#     [-85.603465, 33.788474],
#     [-85.603391, 33.802344],
#     [-85.585985, 33.802095],
#     [-85.585201, 33.84592],
#     [-85.636882, 33.846495],
#     [-85.637126, 33.846497],
#     [-85.637012, 33.875273],
#     [-85.637014, 33.875944],
#     [-85.601899, 33.874865],
#     [-85.601913, 33.875101],
#     [-85.601858, 33.88975],
#     [-85.597063, 33.889703],
#     [-85.532482, 33.889152],
#     [-85.531812, 33.903049],
#     [-85.530094, 33.941423],
#     [-85.49582, 33.942394],
#     [-85.495289, 33.95691],
#     [-85.425627, 33.957069],
#     [-85.425444, 33.960645],
#     [-85.407831, 33.960548],
#     [-85.407637, 33.964204],
#     [-85.398837, 33.964129],
#     [-85.391495, 33.927068],
#     [-85.388717, 33.913044]]]}}

# %%
from platform import python_version

print(python_version())

# %%
# try:
#     conn = MongoClient("mongodb://localhost:27017/")
#     print("Connected Successfully")
# except:
#     print("Could not connect to MongoDB")
    
#set up database connection
conn = "mongodb+srv://project3_group4:project3_group4@cluster0.a6d7ysg.mongodb.net/?retryWrites=true&w=majority"
client = pymongo.MongoClient(conn)

#select db and collection to use
db = client.project3_data
collection = db.data

# insert data
collection.insertMany(mydata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-bd5b703433d7> in <module>
#      14
#      15 # insert data
# ---> 16 collection.insertMany(mydata)
#
# C:\Anaconda\envs\PythonData\lib\site-packages\pymongo\collection.py in __call__(self, *args, **kwargs)
#    3167             "'Collection' object is not callable. If you meant to "
#    3168             "call the '%s' method on a 'Collection' object it is "
# -> 3169             "failing because no such method exists." % self.__name.split(".")[-1]
#    3170         )
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'insertMany' method on a 'Collection' object it is failing because no such method exists.

# %%
result_list = []
results = collection.find()
for result in results:
    del result['_id']
    result_list.append(result)
real_list = {"type": "FeatureCollection", "features": result_list}
real_list

# %%
collection.find_one()

# %%
real_list
